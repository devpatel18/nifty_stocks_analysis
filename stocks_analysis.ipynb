# %%
import pandas as pd
import yfinance as yf

# %%
from pandas_datareader import data as pdr

yf.pdr_override()
# download dataframe
data = pdr.get_data_yahoo("RELIANCE.NS", start="2017-03-27", end="2022-12-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df = pd.DataFrame(data)
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2017-03-27   629.582214   633.371277   617.744385   619.676086   601.998352
# 2017-03-28   623.093689   626.065552   615.218323   617.026184   599.424072
# 2017-03-29   619.973267   624.084290   610.884399   622.425049   604.668884
# 2017-03-30   621.607788   631.390076   620.617188   629.359314   611.405334
# 2017-03-31   627.056152   662.544739   627.056152   654.248352   635.584351
# ...                 ...          ...          ...          ...          ...
# 2022-11-24  2566.000000  2594.000000  2548.199951  2579.100098  2579.100098
# 2022-11-25  2589.000000  2624.899902  2582.100098  2617.600098  2617.600098
# 2022-11-28  2608.899902  2721.050049  2502.000000  2707.550049  2707.550049
# 2022-11-29  2703.949951  2731.649902  2694.000000  2712.199951  2712.199951
# 2022-11-30  2712.500000  2745.449951  2698.199951  2731.350098  2731.350098
#
#               Volume
# Date
# 2017-03-27  14976876
# 2017-03-28  10017936
# 2017-03-29   8733582
# 2017-03-30  12858458
# 2017-03-31  20947737
# ...              ...
# 2022-11-24   4333225
# 2022-11-25   3391988
# 2022-11-28  14549929
# 2022-11-29   5103687
# 2022-11-30  12075137
#
# [1405 rows x 6 columns]

# %%
nifty50 = pd.read_html('https://en.wikipedia.org/wiki/NIFTY_50')[1]

# %%
symbols = nifty50['Symbol'].to_list()

# %%
symbols
# Out:
# ['ADANIENT',
#  'ADANIPORTS',
#  'APOLLOHOSP',
#  'ASIANPAINT',
#  'AXISBANK',
#  'BAJAJ-AUTO',
#  'BAJFINANCE',
#  'BAJAJFINSV',
#  'BHARTIARTL',
#  'BPCL',
#  'BRITANNIA',
#  'CIPLA',
#  'COALINDIA',
#  'DIVISLAB',
#  'DRREDDY',
#  'EICHERMOT',
#  'GRASIM',
#  'HCLTECH',
#  'HDFC',
#  'HDFCBANK',
#  'HDFCLIFE',
#  'HEROMOTOCO',
#  'HINDALCO',
#  'HINDUNILVR',
#  'ICICIBANK',
#  'INDUSINDBK',
#  'INFY',
#  'ITC',
#  'JSWSTEEL',
#  'KOTAKBANK',
#  'LT',
#  'M&M',
#  'MARUTI',
#  'NESTLEIND',
#  'NTPC',
#  'ONGC',
#  'POWERGRID',
#  'RELIANCE',
#  'SBIN',
#  'SBILIFE',
#  'SUNPHARMA',
#  'TATAMOTORS',
#  'TATASTEEL',
#  'TCS',
#  'TATACONSUM',
#  'TECHM',
#  'TITAN',
#  'ULTRACEMCO',
#  'UPL',
#  'WIPRO']

# %%
# df_stock = pd.DataFrame(columns=['Symbol','Company name'])
# for i in tickers:
#     df_stock = pd.concat([df_stock,i],axis = 0,ignore_index = True)

# %%
# df_stock = df_stock.iloc[1:,:]

# %%
# stocks_tickers = list(df_stock['Symbol'].str.replace("NSE:","").str.strip())
# len(stocks_tickers)

# %%
for count in range(len(symbols)):
    symbols[count] = symbols[count] + ".NS"

# %%
symbols
# Out:
# ['ADANIENT.NS',
#  'ADANIPORTS.NS',
#  'APOLLOHOSP.NS',
#  'ASIANPAINT.NS',
#  'AXISBANK.NS',
#  'BAJAJ-AUTO.NS',
#  'BAJFINANCE.NS',
#  'BAJAJFINSV.NS',
#  'BHARTIARTL.NS',
#  'BPCL.NS',
#  'BRITANNIA.NS',
#  'CIPLA.NS',
#  'COALINDIA.NS',
#  'DIVISLAB.NS',
#  'DRREDDY.NS',
#  'EICHERMOT.NS',
#  'GRASIM.NS',
#  'HCLTECH.NS',
#  'HDFC.NS',
#  'HDFCBANK.NS',
#  'HDFCLIFE.NS',
#  'HEROMOTOCO.NS',
#  'HINDALCO.NS',
#  'HINDUNILVR.NS',
#  'ICICIBANK.NS',
#  'INDUSINDBK.NS',
#  'INFY.NS',
#  'ITC.NS',
#  'JSWSTEEL.NS',
#  'KOTAKBANK.NS',
#  'LT.NS',
#  'M&M.NS',
#  'MARUTI.NS',
#  'NESTLEIND.NS',
#  'NTPC.NS',
#  'ONGC.NS',
#  'POWERGRID.NS',
#  'RELIANCE.NS',
#  'SBIN.NS',
#  'SBILIFE.NS',
#  'SUNPHARMA.NS',
#  'TATAMOTORS.NS',
#  'TATASTEEL.NS',
#  'TCS.NS',
#  'TATACONSUM.NS',
#  'TECHM.NS',
#  'TITAN.NS',
#  'ULTRACEMCO.NS',
#  'UPL.NS',
#  'WIPRO.NS']

# %%
price_data = yf.download('RELIANCE.NS',period='max',)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
price_data['1996':'2005']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1996-01-01   15.859429   15.944529   15.754989   15.917452   10.477990
# 1996-01-02   15.878770   15.956133   15.677626   15.793671   10.396508
# 1996-01-03   16.052837   16.783918   15.878770   15.913584   10.475447
# 1996-01-04   15.762726   15.813012   15.553845   15.766594   10.378687
# 1996-01-05   15.704703   15.704703   15.522900   15.658285   10.307389
# ...                ...         ...         ...         ...         ...
# 2005-12-26  129.969955  130.263947  127.958519  128.840454  113.353073
# 2005-12-27  129.196335  134.596268  128.136459  134.132095  118.008629
# 2005-12-28  134.611740  137.690796  134.302292  134.998566  118.770950
# 2005-12-29  134.302292  138.479904  134.302292  137.876465  121.302895
# 2005-12-30  138.944077  139.385040  136.971313  137.597961  121.057884
#
#                Volume
# Date
# 1996-01-01   48051995
# 1996-01-02   77875009
# 1996-01-03   96602936
# 1996-01-04  100099436
# 1996-01-05   76935930
# ...               ...
# 2005-12-26   34403377
# 2005-12-27   38084339
# 2005-12-28   70042777
# 2005-12-29   58712139
# 2005-12-30   31977950
#
# [2597 rows x 6 columns]

# %%
price_data[price_data.columns]
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1996-01-01    15.859429    15.944529    15.754989    15.917452    10.477990
# 1996-01-02    15.878770    15.956133    15.677626    15.793671    10.396508
# 1996-01-03    16.052837    16.783918    15.878770    15.913584    10.475447
# 1996-01-04    15.762726    15.813012    15.553845    15.766594    10.378687
# 1996-01-05    15.704703    15.704703    15.522900    15.658285    10.307389
# ...                 ...          ...          ...          ...          ...
# 2022-11-28  2608.899902  2721.050049  2502.000000  2707.550049  2707.550049
# 2022-11-29  2703.949951  2731.649902  2694.000000  2712.199951  2712.199951
# 2022-11-30  2712.500000  2745.449951  2698.199951  2731.350098  2731.350098
# 2022-12-01  2741.800049  2755.000000  2716.000000  2723.300049  2723.300049
# 2022-12-02  2730.000000  2748.000000  2700.600098  2722.149902  2722.149902
#
#                Volume
# Date
# 1996-01-01   48051995
# 1996-01-02   77875009
# 1996-01-03   96602936
# 1996-01-04  100099436
# 1996-01-05   76935930
# ...               ...
# 2022-11-28   14549929
# 2022-11-29    5103687
# 2022-11-30   12075137
# 2022-12-01    4377696
# 2022-12-02    5348595
#
# [6770 rows x 6 columns]

# %%
rel = yf.Ticker("RELIANCE.NS")

# %%
rel.info
# Out:
# {'ebitdaMargins': None,
#  'profitMargins': None,
#  'grossMargins': None,
#  'operatingCashflow': None,
#  'revenueGrowth': None,
#  'operatingMargins': None,
#  'ebitda': None,
#  'targetLowPrice': 1350,
#  'recommendationKey': 'buy',
#  'grossProfits': 1722910000000,
#  'freeCashflow': None,
#  'targetMedianPrice': 2280,
#  'currentPrice': 2722.15,
#  'earningsGrowth': None,
#  'currentRatio': None,
#  'returnOnAssets': None,
#  'numberOfAnalystOpinions': 29,
#  'targetMeanPrice': 2272.1,
#  'debtToEquity': None,
#  'returnOnEquity': None,
#  'targetHighPrice': 2830,
#  'totalCash': None,
#  'totalDebt': None,
#  'totalRevenue': None,
#  'totalCashPerShare': None,
#  'financialCurrency': 'INR',
#  'maxAge': 1,
#  'revenuePerShare': None,
#  'quickRatio': None,
#  'recommendationMean': 2.1,
#  'exchange': 'NSI',
#  'shortName': 'RELIANCE INDS',
#  'longName': 'Reliance Industries Limited',
#  'exchangeTimezoneName': 'Asia/Kolkata',
#  'exchangeTimezoneShortName': 'IST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '19800000',
#  'quoteType': 'EQUITY',
#  'symbol': 'RELIANCE.NS',
#  'messageBoardId': 'finmb_878373',
#  'market': 'in_market',
#  'previousClose': 2723.3,
#  'regularMarketOpen': 2730,
#  'twoHundredDayAverage': 2546.2998,
#  'trailingAnnualDividendYield': 0,
#  'payoutRatio': None,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 2748,
#  'navPrice': None,
#  'averageDailyVolume10Day': 5814035,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 2723.3,
#  'fiftyDayAverage': 2513.888,
#  'trailingAnnualDividendRate': 0,
#  'open': 2730,
#  'toCurrency': None,
#  'averageVolume10days': 5814035,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 2700.6,
#  'priceHint': 2,
#  'currency': 'INR',
#  'trailingPE': 31.173344,
#  'regularMarketVolume': 5346727,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 18418038210560,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 5037154,
#  'priceToSalesTrailing12Months': None,
#  'dayLow': 2700.6,
#  'ask': 0,
#  'ytdReturn': None,
#  'askSize': 0,
#  'volume': 5346727,
#  'fiftyTwoWeekHigh': 2856.15,
#  'forwardPE': 37.88657,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 2180,
#  'bid': 0,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 0,
#  'dayHigh': 2748,
#  'coinMarketCapLink': None,
#  'regularMarketPrice': 2722.15,
#  'preMarketPrice': None,
#  'logo_url': ''}

# %%
print(rel.info['trailingPE'])
# Out:
# 31.173344

# %%
rel.get_balancesheet()
# Out:
#                                     2021-03-31    2020-03-31    2019-03-31  \
# Intangible Assets                 1.347620e+12  1.364890e+12  1.135470e+12
# Capital Surplus                   7.450800e+11  6.139500e+11  4.116400e+11
# Total Liab                        5.217800e+12  7.045680e+12  6.070140e+12
# Total Stockholder Equity          7.001720e+12  4.491660e+12  3.871120e+12
# Minority Interest                 9.926000e+11  1.218100e+11  8.280000e+10
# Other Current Liab                7.504800e+11  1.720440e+12  1.248750e+12
# Total Assets                      1.321212e+13  1.165915e+13  1.002406e+13
# Common Stock                      6.445000e+10  6.339000e+10  5.926000e+10
# Other Current Assets              4.131000e+11  4.447000e+11  5.487200e+11
# Retained Earnings                 4.601490e+12  2.940490e+12  2.678300e+12
# Other Liab                        7.358100e+11  8.650500e+11  8.218600e+11
# Good Will                         1.021200e+11  1.025900e+11  1.199700e+11
# Treasury Stock                    1.590700e+12  8.738300e+11  7.219200e+11
# Other Assets                      6.860800e+11  6.203900e+11  2.790400e+11
# Cash                              1.739700e+11  3.092000e+11  1.108100e+11
# Total Current Liabilities         2.775680e+12  4.129160e+12  3.173220e+12
# Deferred Long Term Asset Charges  1.147000e+10  2.900000e+10  4.776000e+10
# Short Long Term Debt              2.804700e+11  4.487700e+11  1.556300e+11
# Other Stockholder Equity          1.590700e+12  8.738300e+11  7.219200e+11
# Property Plant Equipment          5.222370e+12  4.950160e+12  4.522930e+12
# Total Current Assets              3.730110e+12  2.582600e+12  2.320530e+12
# Long Term Investments             2.123820e+12  2.038520e+12  1.646120e+12
# Net Tangible Assets               5.551980e+12  3.024180e+12  2.615680e+12
# Short Term Investments            1.304840e+12  6.858700e+11  3.754100e+11
# Net Receivables                   5.892200e+11  2.032500e+11  3.063400e+11
# Long Term Debt                    1.636830e+12  1.976310e+12  2.075060e+12
# Inventory                         8.167200e+11  7.390300e+11  6.756100e+11
# Accounts Payable                  1.088970e+12  9.679900e+11  1.083090e+12
#
#                                     2018-03-31
# Intangible Assets                 1.028430e+12
# Capital Surplus                   4.096900e+11
# Total Liab                        5.193030e+12
# Total Stockholder Equity          2.935060e+12
# Minority Interest                 3.539000e+10
# Other Current Liab                1.292350e+12
# Total Assets                      8.163480e+12
# Common Stock                      5.922000e+10
# Other Current Assets              3.336300e+11
# Retained Earnings                 2.373250e+12
# Other Liab                        6.127600e+11
# Good Will                         5.813000e+10
# Treasury Stock                    9.290000e+10
# Other Assets                      1.639600e+11
# Cash                              4.255000e+10
# Total Current Liabilities         3.138520e+12
# Deferred Long Term Asset Charges  5.075000e+10
# Short Long Term Debt              3.715900e+11
# Other Stockholder Equity          9.290000e+10
# Property Plant Equipment          4.822510e+12
# Total Current Assets              1.837860e+12
# Long Term Investments             2.525900e+11
# Net Tangible Assets               1.848500e+12
# Short Term Investments            3.002900e+11
# Net Receivables                   2.004000e+11
# Long Term Debt                    1.441750e+12
# Inventory                         6.083700e+11
# Accounts Payable                  1.068610e+12

# %%
rel.get_financials()
# Out:
#                                              2021-03-31       2020-03-31  \
# Research Development                               None             None
# Effect Of Accounting Charges                       None             None
# Income Before Tax                        498190000000.0   580500000000.0
# Minority Interest                        992600000000.0   121810000000.0
# Net Income                               491280000000.0   393540000000.0
# Selling General Administrative           148170000000.0   140750000000.0
# Gross Profit                            1722910000000.0  1880090000000.0
# Ebit                                     535050000000.0   673160000000.0
# Operating Income                         535050000000.0   673160000000.0
# Other Operating Expenses                 773970000000.0   844150000000.0
# Interest Expense                        -179070000000.0  -198610000000.0
# Extraordinary Items                                None             None
# Non Recurring                                      None             None
# Other Items                                        None             None
# Income Tax Expense                        17220000000.0   137260000000.0
# Total Revenue                           4669240000000.0  5975350000000.0
# Total Operating Expenses                4134190000000.0  5302190000000.0
# Cost Of Revenue                         2946330000000.0  4095260000000.0
# Total Other Income Expense Net           -36860000000.0   -92660000000.0
# Discontinued Operations                            None             None
# Net Income From Continuing Ops           480970000000.0   443240000000.0
