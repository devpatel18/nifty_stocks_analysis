# %%
import pandas as pd
import yfinance as yf

# %%
from pandas_datareader import data as pdr

yf.pdr_override()
# download dataframe
data = pdr.get_data_yahoo("RELIANCE.NS", start="2017-03-27", end="2022-12-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df = pd.DataFrame(data)
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2017-03-27   629.582214   633.371277   617.744385   619.676086   601.998352
# 2017-03-28   623.093689   626.065552   615.218323   617.026184   599.424072
# 2017-03-29   619.973267   624.084290   610.884399   622.425049   604.668884
# 2017-03-30   621.607788   631.390076   620.617188   629.359314   611.405334
# 2017-03-31   627.056152   662.544739   627.056152   654.248352   635.584351
# ...                 ...          ...          ...          ...          ...
# 2022-11-24  2566.000000  2594.000000  2548.199951  2579.100098  2579.100098
# 2022-11-25  2589.000000  2624.899902  2582.100098  2617.600098  2617.600098
# 2022-11-28  2608.899902  2721.050049  2502.000000  2707.550049  2707.550049
# 2022-11-29  2703.949951  2731.649902  2694.000000  2712.199951  2712.199951
# 2022-11-30  2712.500000  2745.449951  2698.199951  2731.350098  2731.350098
#
#               Volume
# Date
# ...

# %%
nifty50 = pd.read_html('https://en.wikipedia.org/wiki/NIFTY_50')[1]

# %%
symbols = nifty50['Symbol'].to_list()

# %%
symbols
# Out:
# ['ADANIENT',
#  'ADANIPORTS',
#  'APOLLOHOSP',
#  'ASIANPAINT',
#  'AXISBANK',
#  'BAJAJ-AUTO',
#  'BAJFINANCE',
#  'BAJAJFINSV',
#  'BHARTIARTL',
#  'BPCL',
#  'BRITANNIA',
#  'CIPLA',
#  'COALINDIA',
#  'DIVISLAB',
#  'DRREDDY',
#  'EICHERMOT',
#  'GRASIM',
#  'HCLTECH',
#  'HDFC',
#  'HDFCBANK',
#  'HDFCLIFE',
#  'HEROMOTOCO',
#  'HINDALCO',
#  'HINDUNILVR',
#  'ICICIBANK',
#  'INDUSINDBK',
#  'INFY',
#  'ITC',
#  'JSWSTEEL',
#  'KOTAKBANK',
#  'LT',
#  'M&M',
#  'MARUTI',
#  'NESTLEIND',
#  'NTPC',
#  'ONGC',
#  'POWERGRID',
#  'RELIANCE',
#  'SBIN',
#  'SBILIFE',
#  'SUNPHARMA',
#  'TATAMOTORS',
#  'TATASTEEL',
#  'TCS',
#  'TATACONSUM',
#  'TECHM',
#  'TITAN',
#  'ULTRACEMCO',
#  'UPL',
#  'WIPRO']

# %%
# df_stock = pd.DataFrame(columns=['Symbol','Company name'])
# for i in tickers:
#     df_stock = pd.concat([df_stock,i],axis = 0,ignore_index = True)

# %%
# df_stock = df_stock.iloc[1:,:]

# %%
# stocks_tickers = list(df_stock['Symbol'].str.replace("NSE:","").str.strip())
# len(stocks_tickers)

# %%
for count in range(len(symbols)):
    symbols[count] = symbols[count] + ".NS"

# %%
symbols
# Out:
# ['ADANIENT.NS',
#  'ADANIPORTS.NS',
#  'APOLLOHOSP.NS',
#  'ASIANPAINT.NS',
#  'AXISBANK.NS',
#  'BAJAJ-AUTO.NS',
#  'BAJFINANCE.NS',
#  'BAJAJFINSV.NS',
#  'BHARTIARTL.NS',
#  'BPCL.NS',
#  'BRITANNIA.NS',
#  'CIPLA.NS',
#  'COALINDIA.NS',
#  'DIVISLAB.NS',
#  'DRREDDY.NS',
#  'EICHERMOT.NS',
#  'GRASIM.NS',
#  'HCLTECH.NS',
#  'HDFC.NS',
#  'HDFCBANK.NS',
#  'HDFCLIFE.NS',
#  'HEROMOTOCO.NS',
#  'HINDALCO.NS',
#  'HINDUNILVR.NS',
#  'ICICIBANK.NS',
#  'INDUSINDBK.NS',
#  'INFY.NS',
#  'ITC.NS',
#  'JSWSTEEL.NS',
#  'KOTAKBANK.NS',
#  'LT.NS',
#  'M&M.NS',
#  'MARUTI.NS',
#  'NESTLEIND.NS',
#  'NTPC.NS',
#  'ONGC.NS',
#  'POWERGRID.NS',
#  'RELIANCE.NS',
#  'SBIN.NS',
#  'SBILIFE.NS',
#  'SUNPHARMA.NS',
#  'TATAMOTORS.NS',
#  'TATASTEEL.NS',
#  'TCS.NS',
#  'TATACONSUM.NS',
#  'TECHM.NS',
#  'TITAN.NS',
#  'ULTRACEMCO.NS',
#  'UPL.NS',
#  'WIPRO.NS']

# %%
price_data = yf.download('RELIANCE.NS',period='max',)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
price_data['1996':'2005']
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1996-01-01 00:00:00+05:30   15.859429   15.944529   15.754989   15.917452
# 1996-01-02 00:00:00+05:30   15.878770   15.956133   15.677626   15.793671
# 1996-01-03 00:00:00+05:30   16.052837   16.783918   15.878770   15.913584
# 1996-01-04 00:00:00+05:30   15.762726   15.813012   15.553845   15.766594
# 1996-01-05 00:00:00+05:30   15.704703   15.704703   15.522900   15.658285
# ...                               ...         ...         ...         ...
# 2005-12-26 00:00:00+05:30  129.969955  130.263947  127.958519  128.840454
# 2005-12-27 00:00:00+05:30  129.196335  134.596268  128.136459  134.132095
# 2005-12-28 00:00:00+05:30  134.611740  137.690796  134.302292  134.998566
# 2005-12-29 00:00:00+05:30  134.302292  138.479904  134.302292  137.876465
# 2005-12-30 00:00:00+05:30  138.944077  139.385040  136.971313  137.597961
#
#                             Adj Close     Volume
# Date
# ...

# %%
price_data[price_data.columns]
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1996-01-01 00:00:00+05:30    15.859429    15.944529    15.754989    15.917452
# 1996-01-02 00:00:00+05:30    15.878770    15.956133    15.677626    15.793671
# 1996-01-03 00:00:00+05:30    16.052837    16.783918    15.878770    15.913584
# 1996-01-04 00:00:00+05:30    15.762726    15.813012    15.553845    15.766594
# 1996-01-05 00:00:00+05:30    15.704703    15.704703    15.522900    15.658285
# ...                                ...          ...          ...          ...
# 2023-01-16 00:00:00+05:30  2472.699951  2479.649902  2427.000000  2444.100098
# 2023-01-17 00:00:00+05:30  2458.000000  2483.000000  2450.600098  2478.800049
# 2023-01-18 00:00:00+05:30  2473.500000  2491.100098  2460.350098  2474.699951
# 2023-01-19 00:00:00+05:30  2472.899902  2481.149902  2456.649902  2472.050049
# 2023-01-20 00:00:00+05:30  2475.000000  2475.000000  2437.250000  2442.649902
#
# ...

# %%
rel = yf.Ticker("RELIANCE.NS")

# %%
rel.info
# Out:
# {'ebitdaMargins': None,
#  'profitMargins': None,
#  'grossMargins': None,
#  'operatingCashflow': None,
#  'revenueGrowth': None,
#  'operatingMargins': None,
#  'ebitda': None,
#  'targetLowPrice': 1350,
#  'recommendationKey': 'buy',
#  'grossProfits': 1722910000000,
#  'freeCashflow': None,
#  'targetMedianPrice': 2280,
#  'currentPrice': 2442.65,
#  'earningsGrowth': None,
#  'currentRatio': None,
#  'returnOnAssets': None,
#  'numberOfAnalystOpinions': 29,
#  'targetMeanPrice': 2272.1,
#  'debtToEquity': None,
#  'returnOnEquity': None,
#  'targetHighPrice': 2830,
#  'totalCash': None,
#  'totalDebt': None,
#  'totalRevenue': None,
#  'totalCashPerShare': None,
#  'financialCurrency': 'INR',
#  'maxAge': 1,
#  'revenuePerShare': None,
#  'quickRatio': None,
#  'recommendationMean': 2.1,
#  'exchange': 'NSI',
#  'shortName': 'RELIANCE INDS',
#  'longName': 'Reliance Industries Limited',
#  'exchangeTimezoneName': 'Asia/Kolkata',
#  'exchangeTimezoneShortName': 'IST',
# ...

# %%
print(rel.info['trailingPE'])
# Out:
# 27.972584

# %%
rel.get_balancesheet()
# Out:
#                                                   2022-03-31  \
# TotalAssets                                 14996650000000.0
# CurrentAssets                                3470190000000.0
# CashCashEquivalentsAndShortTermInvestments   1529000000000.0
# CashAndCashEquivalents                        335090000000.0
# CashFinancial                                  88200000000.0
# ...                                                      ...
# TangibleBookValue                            5476870000000.0
# TotalDebt                                    2819740000000.0
# NetDebt                                      2327960000000.0
# ShareIssued                                     6765994014.0
# OrdinarySharesNumber                            6765994014.0
#
#                                                   2021-03-31  \
# TotalAssets                                 13212120000000.0
# CurrentAssets                                3730110000000.0
# ...

# %%
rel.get_financials()
# Out:
#                                                          2022-03-31  \
# TotalRevenue                                        6999620000000.0
# OperatingRevenue                                    6999620000000.0
# CostOfRevenue                                       5336130000000.0
# GrossProfit                                         1663490000000.0
# OperatingExpense                                     855870000000.0
# SellingGeneralAndAdministration                      248690000000.0
# GeneralAndAdministrativeExpense                       88910000000.0
# RentAndLandingFees                                     5780000000.0
# SellingAndMarketingExpense                           159780000000.0
# OtherOperatingExpenses                               420940000000.0
# OperatingIncome                                      807620000000.0
# NetNonOperatingInterestIncomeExpense                 -19260000000.0
# InterestIncomeNonOperating                           125290000000.0
# ...

# %%
rel.get_earnings()
# Out:
#             Revenue      Earnings
# Year
# 2018  4082650000000  360750000000
# 2019  5692090000000  395880000000
# 2020  5975350000000  393540000000
# 2021  4669240000000  491280000000

# %%
rel.get_dividends()
# Out:
# Date
# 1996-05-24 00:00:00+05:30    0.742958
# 1997-05-16 00:00:00+05:30    0.804871
# 1998-05-06 00:00:00+05:30    0.866784
# 1999-05-07 00:00:00+05:30    0.928697
# 2000-04-06 00:00:00+05:30    0.990610
# 2001-04-26 00:00:00+05:30    1.052523
# 2002-10-23 00:00:00+05:30    1.176349
# 2003-05-23 00:00:00+05:30    1.238263
# 2004-05-20 00:00:00+05:30    1.300176
# 2005-05-12 00:00:00+05:30    1.857394
# 2006-06-01 00:00:00+05:30    2.476525
# 2007-03-21 00:00:00+05:30    2.724178
# 2008-05-08 00:00:00+05:30    3.219483
# 2009-10-16 00:00:00+05:30    3.219483
# 2010-05-10 00:00:00+05:30    3.467135
# 2011-05-05 00:00:00+05:30    3.962440
# 2012-05-31 00:00:00+05:30    4.210093
# 2013-05-10 00:00:00+05:30    4.457745
# 2014-05-16 00:00:00+05:30    4.705398
# 2015-05-08 00:00:00+05:30    4.953050
# 2016-03-17 00:00:00+05:30    5.200703
# 2017-07-13 00:00:00+05:30    5.448355
# 2018-06-27 00:00:00+05:30    5.943660
# 2019-08-02 00:00:00+05:30    6.438965
# ...

# %%
rel.get_actions()
# Out:
#                            Dividends  Stock Splits
# Date
# 1996-05-24 00:00:00+05:30   0.742958           0.0
# 1997-05-16 00:00:00+05:30   0.804871           0.0
# 1997-10-27 00:00:00+05:30   0.000000           2.0
# 1998-05-06 00:00:00+05:30   0.866784           0.0
# 1999-05-07 00:00:00+05:30   0.928697           0.0
# 2000-04-06 00:00:00+05:30   0.990610           0.0
# 2001-04-26 00:00:00+05:30   1.052523           0.0
# 2002-10-23 00:00:00+05:30   1.176349           0.0
# 2003-05-23 00:00:00+05:30   1.238263           0.0
# 2004-05-20 00:00:00+05:30   1.300176           0.0
# 2005-05-12 00:00:00+05:30   1.857394           0.0
# 2006-06-01 00:00:00+05:30   2.476525           0.0
# 2007-03-21 00:00:00+05:30   2.724178           0.0
# 2008-05-08 00:00:00+05:30   3.219483           0.0
# 2009-10-16 00:00:00+05:30   3.219483           0.0
# 2009-11-26 00:00:00+05:30   0.000000           2.0
# 2010-05-10 00:00:00+05:30   3.467135           0.0
# ...
